# %%
#resample the images to MNI152
from nilearn.image import resample_to_img, load_img
from nilearn.datasets import load_mni152_template
import nibabel as nib
import os

# %%
subjects = ['patient_05_part1L',
            'patient_05_part1R',
            'patient_05_part2L',
            'patient_05_part2R',
            'patient_06',
            'patient_08',
            'patient_10',
            'patient_11_part1',
            'patient_11_part2',
            'patient_13',
            'patient_14_part1_left',
            'patient_14_part2_left',
            'patient_14_part1_right',
            'patient_14_part2_right',
            'patient_16',
            'patient_17',
            'patient_21',
            'patient_22',
            'patient_23',
            'patient_25',
            ]

# %%
meg_niftis = {
    "patient_05_part1L": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_05_part1L_to_fsaverage.nii.gz",
    "patient_05_part1R": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_05_part1R_to_fsaverage.nii.gz",
    "patient_05_part2L": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_05_part2L_to_fsaverage.nii.gz",
    "patient_05_part2R": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_05_part2R_to_fsaverage.nii.gz",
    "patient_06": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_06_to_fsaverage.nii.gz",
    "patient_08": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_08_to_fsaverage.nii.gz",
    "patient_10": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_10_to_fsaverage.nii.gz",
    "patient_11_part1": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_11_part1_to_fsaverage.nii.gz",
    "patient_11_part2": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_11_part2_to_fsaverage.nii.gz",
    "patient_13": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_13_to_fsaverage.nii.gz",
    "patient_14_part1_left": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_14_part1_left_to_fsaverage.nii.gz",
    "patient_14_part2_left": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_14_part2_left_to_fsaverage.nii.gz",
    "patient_14_part1_right": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_14_part1_right_to_fsaverage.nii.gz",
    "patient_14_part2_right": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_14_part2_right_to_fsaverage.nii.gz",
    "patient_16": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_16_to_fsaverage.nii.gz",
    "patient_17": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_17_to_fsaverage.nii.gz",
    "patient_21": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_21_to_fsaverage.nii.gz",
    "patient_22": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_22_to_fsaverage.nii.gz",
    "patient_23": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_23_to_fsaverage.nii.gz",
    "patient_25": "/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/morphed_niftis/theta/theta_patient_25_to_fsaverage.nii.gz"
}

# %%
#load MNI152 template
mni152_template = load_mni152_template()

# %%
for subject, file_path in meg_niftis.items():
    img = load_img(file_path)

    img_mni152 = resample_to_img(img, mni152_template, interpolation='linear')

    #save it
    output_path = f"/Users/Lea/Desktop/PROJECT_DATA_ANALYSIS/resampled_mni152/theta/theta_{subject}_to_mni152.nii.gz"
    nib.save(img_mni152, output_path)
# Out:
# /var/folders/hp/k3clndsn2sj608qsb4fl5zvr0000gn/T/ipykernel_65666/3060636708.py:4: FutureWarning: 'force_resample' will be set to 'True' by default in Nilearn 0.13.0.
# Use 'force_resample=True' to suppress this warning.
#   img_mni152 = resample_to_img(img, mni152_template, interpolation='linear')
# /Users/lea/Desktop/PROJECT_DATA_ANALYSIS/venv/lib/python3.13/site-packages/nilearn/image/resampling.py:805: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   return resample_img(
# /var/folders/hp/k3clndsn2sj608qsb4fl5zvr0000gn/T/ipykernel_65666/3060636708.py:4: FutureWarning: 'force_resample' will be set to 'True' by default in Nilearn 0.13.0.
# Use 'force_resample=True' to suppress this warning.
#   img_mni152 = resample_to_img(img, mni152_template, interpolation='linear')
# ...
